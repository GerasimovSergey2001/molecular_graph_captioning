# %%
# !git clone https://github.com/GerasimovSergey2001/molecular_graph_captioning
# Out:
# Cloning into 'molecular_graph_captioning'...
# remote: Enumerating objects: 603, done.
# remote: Counting objects: 100% (603/603), done.
# remote: Compressing objects: 100% (321/321), done.
# remote: Total 603 (delta 308), reused 546 (delta 251), pack-reused 0 (from 0)
# Receiving objects: 100% (603/603), 34.07 MiB | 15.69 MiB/s, done.
# Resolving deltas: 100% (308/308), done.
# Filtering content: 100% (16/16), 1.81 GiB | 50.07 MiB/s, done.

# %%
# !pip install torch==2.8.0 torchvision==0.23.0 torchaudio==2.8.0 --index-url https://download.pytorch.org/whl/cu126 -q
# !pip install torch_geometric -q
# !pip install pyg_lib torch_scatter torch_sparse torch_cluster torch_spline_conv -f https://data.pyg.org/whl/torch-2.8.0+cu126.html -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 322.4/322.4 MB 120.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 821.8/821.8 MB 1.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.4/7.4 MB 142.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.5/3.5 MB 114.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 155.6/155.6 MB 16.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.7/63.7 kB 5.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 77.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.8/4.8 MB 102.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.9/10.9 MB 79.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.2/5.2 MB 116.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 93.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 67.4 MB/s eta 0:00:00

# %%
# !pip install "transformers>=4.30.0" "rdkit>=2023.3.1" "nltk>=3.8.0"  "matplotlib" tqdm  "timm>=1.0.23" "peft>=0.18.0" "ogb>=1.3.6"  "sacrebleu>=2.5.1" "bert-score>=0.3.13"
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.8/51.8 kB 5.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 36.4/36.4 MB 67.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.6/2.6 MB 99.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.8/78.8 kB 7.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 104.1/104.1 kB 9.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.1/61.1 kB 5.4 MB/s eta 0:00:00
# ...
#   Attempting uninstall: timm
#     Found existing installation: timm 1.0.22
#     Uninstalling timm-1.0.22:
#       Successfully uninstalled timm-1.0.22
# ...

# %%
from huggingface_hub import hf_hub_download
project_path = "/content/molecular_graph_captioning/checkpoints"
for file_name in ["graphcl_80.pth","gnn_stage2.pth", "mlp_adapter_stage1.pth", "mlp_adapter_stage2.pth"]:
  hf_hub_download(
    repo_id="SergeiGerasimov/galactica_full_final",
    filename=file_name,
    local_dir=project_path,
    repo_type="model"
)

# %%
# %cd molecular_graph_captioning
# Out:
# /content/molecular_graph_captioning

# %%
import os

# !mkdir -p data

file_id = '1Q1XP1ce_cBluyy9Is896QTH7Hx6UGKgh'
download_url = f'https://drive.google.com/uc?id={file_id}'

# !gdown {file_id} -O ./data.zip

# !unzip -qo ./data.zip -d ./data/

# !rm ./data.zip

# !mv ./data/data/* ./data/ 2>/dev/null || :
# !rm -rf ./data/data

os.environ["PYTORCH_CUDA_ALLOC_CONF"] = "expandable_segments:True"

# !ls -l data
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Текущая директория: /content/molecular_graph_captioning
# Файлы в папке data:
# total 199588
# drwxr-xr-x 3 root root      4096 Jan 11 15:57 __MACOSX
# -rw-rw-r-- 1 root root   6079568 Jan  4 11:55 test_graphs.pkl
# -rw-rw-r-- 1 root root 191726900 Jan  4 11:55 train_graphs.pkl
# -rw-rw-r-- 1 root root   6560619 Jan  4 11:55 validation_graphs.pkl

# %%
# %matplotlib inline

# %%
# !python3 -m scripts.stage1
# Out:
# config.json: 100% 385/385 [00:00<00:00, 1.96MB/s]
# vocab.txt: 228kB [00:00, 48.9MB/s]
# Loading graphs from: ./data/train_graphs.pkl
# Loaded 31008 graphs
# Loading graphs from: ./data/validation_graphs.pkl
# Loaded 1000 graphs
# 2026-01-09 12:02:13.001624: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-01-09 12:02:13.026180: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# ...

# %%
# !python3 -m scripts.stage2
# Out:
# 2026-01-10 11:53:17.449813: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-01-10 11:53:17.468486: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1768045997.492630    3577 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1768045997.499780    3577 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# !python3 -m scripts.stage3
# Out:
# 2026-01-10 15:58:02.589987: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-01-10 15:58:02.606791: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1768060682.628187    2152 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1768060682.634711    2152 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# !python3 -m scripts.test_results
# Out:
# 2026-01-11 15:25:29.194350: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-01-11 15:25:29.211339: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1768145129.232891    2400 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1768145129.239424    2400 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...
